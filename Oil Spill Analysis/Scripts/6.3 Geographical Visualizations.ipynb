# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib
import os
import folium
import json

# %%
# %matplotlib inline

# %% [markdown]
# # 02. Import Data

# %%
#JSON file
state_geo = r'C:\Users\byl19\OneDrive\Desktop\states.json'

# %%
path = r'C:\Users\byl19\Acheivment 6\Acheivment 6'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Cleaned-Oil-Data.csv'), index_col = False)

# %% [markdown]
# # 03. Wrangling Data

# %%
df.columns
# Out:
# Index(['Report Number', 'Accident Year', 'Accident Date', 'Accident Time',
#        'Operator ID', 'Operator Name', 'Pipeline/Facility Name',
#        'Pipeline Location', 'Pipeline Type', 'Liquid Type', 'Accident City',
#        'Accident County', 'Accident State', 'Cause Category',
#        'Cause Subcategory', 'Unintentional Release (Barrels)',
#        'Intentional Release (Barrels)', 'Liquid Recovery (Barrels)',
#        'Net Loss (Barrels)', 'Liquid Ignition', 'Liquid Explosion',
#        'Pipeline Shutdown', 'Shutdown Date/Time', 'Restart Date/Time',
#        'Public Evacuations', 'Property Damage Costs', 'Lost Commodity Costs',
#        'Public/Private Property Damage Costs', 'Emergency Response Costs',
#        'Environmental Remediation Costs', 'Other Costs', 'All Costs',
#        'Time Category'],
#       dtype='object')

# %%
df['Accident State'].value_counts()
# Out:
# TX    1004
# OK     236
# LA     169
# CA     153
# KS     150
# IL     108
# WY      98
# NJ      85
# MN      59
# IN      57
# NM      57
# OH      53
# ND      49
# IA      46
# PA      45
# MO      42
# MS      32
# MT      30
# MI      29
# WI      27
# CO      24
# NE      22
# AL      21
# VA      20
# GA      17
# SC      16
# NC      15
# NY      14
# KY      14
# AR      13
# AK      11
# SD       9
# UT       8
# MD       8
# WA       8
# FL       7
# TN       7
# ID       4
# OR       4
# HI       3
# WV       2
# CT       2
# MA       2
# PR       1
# ME       1
# NV       1
# Name: Accident State, dtype: int64

# %% [markdown]
# #### Our states are in abbreviated format which is different than our JSON file. We will need to switch that so the two can work together.

# %%
#states dictionary
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
#replacing states
df['Accident State'] = df['Accident State'].replace(states)

# %%
#checking states
df['Accident State'].head()
# Out:
# 0    West Virginia
# 1            Texas
# 2        Louisiana
# 3         Illinois
# 4     North Dakota
# Name: Accident State, dtype: object

# %%
#making plottable dataframe
data = pd.DataFrame(df['Accident State'].value_counts().reset_index().values, columns=["State", "Count of Spills"])
dataindex = data.sort_index(axis = 0, ascending=True)
dataindex
# Out:
#              State Count of Spills
# 0            Texas            1004
# 1         Oklahoma             236
# 2        Louisiana             169
# 3       California             153
# 4           Kansas             150
# 5         Illinois             108
# 6          Wyoming              98
# 7       New Jersey              85
# 8        Minnesota              59
# 9          Indiana              57
# 10      New Mexico              57
# 11            Ohio              53
# 12    North Dakota              49
# 13            Iowa              46
# 14    Pennsylvania              45
# 15        Missouri              42
# 16     Mississippi              32
# 17         Montana              30
# 18        Michigan              29
# 19       Wisconsin              27
# 20        Colorado              24
# 21        Nebraska              22
# 22         Alabama              21
# 23        Virginia              20
# 24         Georgia              17
# 25  South Carolina              16
# 26  North Carolina              15
# 27        New York              14
# 28        Kentucky              14
# 29        Arkansas              13
# 30          Alaska              11
# 31    South Dakota               9
# 32            Utah               8
# 33        Maryland               8
# 34      Washington               8
# 35         Florida               7
# 36       Tennessee               7
# 37           Idaho               4
# 38          Oregon               4
# 39          Hawaii               3
# 40   West Virginia               2
# 41     Connecticut               2
# 42   Massachusetts               2
# 43     Puerto Rico               1
# 44           Maine               1
# 45          Nevada               1

# %%
#thresholds for our legand
ticks = [1,25,100,250,1004]

# %%
#creating map
statemap = folium.Map(location = [60, -100], zoom_start = 1.5)

folium.Choropleth(
    geo_data = state_geo, 
    data = dataindex,
    columns = ['State', 'Count of Spills'],
    key_on = 'feature.properties.name', 
    threshold_scale = ticks,
    fill_color = 'GnBu', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "Count of Spills").add_to(statemap)
folium.LayerControl().add_to(statemap)

statemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a52015df26069cae33471e31ee75738 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a52015df26069cae33471e31ee75738&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a52015df26069cae33471e31ee75738 = L.map(
#                 &quot;map_9a52015df26069cae33471e31ee75738&quot;,
#                 {
#                     center: [60.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f51d0f2662b563df666511d67691e07f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a52015df26069cae33471e31ee75738);
#
#
#             var choropleth_f74034a1a25a4762bb267b98234ea566 = L.featureGroup(
#                 {}
#             ).addTo(map_9a52015df26069cae33471e31ee75738);
#
#
#         function geo_json_9210297a59ff821dbd910693eac248d6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AZ&quot;: case &quot;DE&quot;: case &quot;NH&quot;: case &quot;RI&quot;: case &quot;VT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;IL&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;OK&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7bccc4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;IN&quot;: case &quot;IA&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;ND&quot;: case &quot;OH&quot;: case &quot;PA&quot;: case &quot;WI&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bae4bc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;TX&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2b8cbe&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f0f9e8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_9210297a59ff821dbd910693eac248d6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9210297a59ff821dbd910693eac248d6 = L.geoJson(null, {
#                 onEachFeature: geo_json_9210297a59ff821dbd910693eac248d6_onEachFeature,
#
#                 style: geo_json_9210297a59ff821dbd910693eac248d6_styler,
#         });
#
#         function geo_json_9210297a59ff821dbd910693eac248d6_add (data) {
#             geo_json_9210297a59ff821dbd910693eac248d6
#                 .addData(data)
#                 .addTo(choropleth_f74034a1a25a4762bb267b98234ea566);
#         }
#             geo_json_9210297a59ff821dbd910693eac248d6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469], [-131.645836, 55.304197], [-131.749898, 55.128935], [-131.832052, 55.189182], [-131.832052, 55.42469]]], [[[-132

# %% [markdown]
# #### We have the map with our states, I made the ticks a custom distance apart since the highest value is so much bigger than the second highest and now we can clearly see the data for all states. To see a more specific area of the spills, sorting them by counties will give us more specific locations

# %%
#save map
statemap.save('State_Data.html')

# %%
county_geo = r'C:\Users\byl19\OneDrive\Desktop\counties.json'

# %%
df['Accident County'].value_counts()
# Out:
# HARRIS            167
# JEFFERSON         106
# LOS ANGELES        52
# PAYNE              50
# MIDLAND            49
#                  ...
# REFUGIO COUNTY      1
# ARAPAHOE            1
# FAYETTE             1
# ADAMS COUNTY        1
# GONZALES            1
# Name: Accident County, Length: 678, dtype: int64

# %%
#Counties are in all caps which is different from geojson file

# %%
df['Accident County'] = df['Accident County'].str.lower()

# %%
df['Accident County'] = df['Accident County'].str.title()

# %% [markdown]
# #### I lowercased everything and then used the command .title becasue just capitalizing made the counties with 2 words in their name incorrect as the first word was capitalizd but the second was not. Lower casing everything and then using .title capitalized both words in the name.

# %%
df['Accident County'].value_counts()
# Out:
# Harris            167
# Jefferson         106
# Los Angeles        52
# Payne              50
# Midland            49
#                  ...
# Refugio County      1
# Arapahoe            1
# Fayette             1
# Adams County        1
# Gonzales            1
# Name: Accident County, Length: 678, dtype: int64

# %%
#Matching JSON file
df['Accident County'] = df['Accident County'].str.replace(' County', '')

# %%
#create plottable datafrom for counties
counties = pd.DataFrame(df['Accident County'].value_counts().reset_index().values, columns=("County", "Count of Spills"))
countiesindex = counties.sort_index(axis = 0, ascending=True)

# %%
countiesindex
# Out:
#           County Count of Spills
# 0         Harris             169
# 1      Jefferson             107
# 2    Los Angeles              56
# 3          Payne              51
# 4        Midland              49
# ..           ...             ...
# 621     La Plata               1
# 622        Miami               1
# 623      Bannock               1
# 624       Clarke               1
# 625     Gonzales               1
#
# [626 rows x 2 columns]

# %%
#threshold for counties legand
ticks2 = [1,10,30,85,150,200]

# %%
#counties map
countiesmap = folium.Map(location = [40, -100], zoom_start = 3.3)

folium.Choropleth(
    geo_data = county_geo, 
    data = countiesindex,
    columns = ('County', 'Count of Spills'),
    key_on = 'feature.properties.name', 
    threshold_scale = ticks2,
    fill_color = 'GnBu', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "spills").add_to(countiesmap)
folium.LayerControl().add_to(countiesmap)

countiesmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f5b98da3b0e072fd280ae44e5aeae61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f5b98da3b0e072fd280ae44e5aeae61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f5b98da3b0e072fd280ae44e5aeae61 = L.map(
#                 &quot;map_6f5b98da3b0e072fd280ae44e5aeae61&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3.3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edbd1c8b881df5dec44f3d04d01930d6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f5b98da3b0e072fd280ae44e5aeae61);
#
#
#             var choropleth_ea9a9851addd7b503e7de1d20c3e1e08 = L.featureGroup(
#                 {}
#             ).addTo(map_6f5b98da3b0e072fd280ae44e5aeae61);
#
#
#         function geo_json_44dc3832ea8605cf92bd366956dd2870_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1013&quot;: case &quot;1071&quot;: case &quot;1089&quot;: case &quot;1093&quot;: case &quot;1101&quot;: case &quot;1117&quot;: case &quot;1129&quot;: case &quot;5053&quot;: case &quot;5067&quot;: case &quot;5071&quot;: case &quot;5087&quot;: case &quot;5089&quot;: case &quot;5097&quot;: case &quot;5113&quot;: case &quot;5139&quot;: case &quot;5143&quot;: case &quot;6013&quot;: case &quot;6059&quot;: case &quot;8035&quot;: case &quot;8057&quot;: case &quot;8121&quot;: case &quot;12063&quot;: case &quot;12077&quot;: case &quot;12079&quot;: case &quot;12083&quot;: case &quot;12095&quot;: case &quot;12105&quot;: case &quot;12125&quot;: case &quot;12133&quot;: case &quot;13075&quot;: case &quot;13097&quot;: case &quot;13157&quot;: case &quot;13167&quot;: case &quot;13179&quot;: case &quot;13195&quot;: case &quot;13197&quot;: case &quot;13209&quot;: case &quot;13233&quot;: case &quot;13291&quot;: case &quot;13303&quot;: case &quot;16035&quot;: case &quot;16065&quot;: case &quot;16087&quot;: case &quot;17031&quot;: case &quot;17041&quot;: case &quot;17069&quot;: case &quot;17077&quot;: case &quot;17087&quot;: case &quot;17119&quot;: case &quot;17121&quot;: case &quot;17135&quot;: case &quot;17173&quot;: case &quot;17181&quot;: case &quot;17189&quot;: case &quot;17197&quot;: case &quot;18003&quot;: case &quot;18035&quot;: case &quot;18053&quot;: case &quot;18071&quot;: case &quot;18081&quot;: case &quot;18095&quot;: case &quot;18097&quot;: case &quot;18107&quot;: case &quot;18117&quot;: case &quot;18145&quot;: case &quot;18161&quot;: case &quot;18175&quot;: case &quot;19023&quot;: case &quot;19055&quot;: case &quot;19083&quot;: case &quot;19097&quot;: case &quot;19103&quot;: case &quot;19117&quot;: case &quot;19121&quot;: case &quot;19125&quot;: case &quot;19137&quot;: case &quot;19153&quot;: case &quot;19165&quot;: case &quot;19175&quot;: case &quot;19183&quot;: case &quot;20001&quot;: case &quot;20015&quot;: case &quot;20045&quot;: case &quot;20067&quot;: case &quot;20085&quot;: case &quot;20091&quot;: case &quot;20115&quot;: case &quot;20125&quot;: case &quot;20201&quot;: case &quot;20203&quot;: case &quot;20209&quot;: case &quot;21003&quot;: case &quot;21031&quot;: case &quot;21043&quot;: case &quot;21081&quot;: case &quot;21093&quot;: case &quot;21109&quot;: case &quot;21115&quot;: case &quot;21151&quot;: case &quot;21155&quot;: case &quot;21173&quot;: case &quot;21211&quot;: case &quot;21225&quot;: case &quot;21229&quot;: case &quot;22003&quot;: case &quot;22019&quot;: case &quot;22033&quot;: case &quot;22037&quot;: case &quot;22043&quot;: case &quot;22049&quot;: case &quot;22057&quot;: case &quot;22065&quot;: case &quot;22093&quot;: case &quot;22111&quot;: case &quot;22117&quot;: case &quot;23029&quot;: case &quot;24031&quot;: case &quot;24043&quot;: case &quot;26075&quot;: case &quot;27029&quot;: case &quot;27031&quot;: case &quot;27041&quot;: case &quot;27051&quot;: case &quot;27061&quot;: case &quot;27063&quot;: case &quot;27119&quot;: case &quot;27163&quot;: case &quot;28059&quot;: case &quot;28089&quot;: case &quot;28091&quot;: case &quot;28097&quot;: case &quot;28145&quot;: case &quot;28151&quot;: case &quot;29023&quot;: case &quot;29035&quot;: case &quot;29067&quot;: case &quot;29095&quot;: case &quot;29101&quot;: case &quot;29123&quot;: case &quot;29127&quot;: case &quot;29139&quot;: case &quot;29167&quot;: case &quot;29205&quot;: case &quot;29221&quot;: case &quot;30011&quot;: case &quot;30051&quot;: case &quot;30057&quot;: case &quot;31023&quot;: case &quot;31055&quot;: case &quot;31075&quot;: case &quot;31097&quot;: case &quot;31119&quot;: case &quot;31143&quot;: case &quot;31177&quot;: case &quot;3

# %% [markdown]
# #### There are a good amount of counties that do not have a documented oil spill from 2010 to 2017. I would love to find updated data on this so my map could be more updated. This map does however give a good picture on the counties who have had a lot of oil spills, specifically Harris county in east texas. I make the ticks for the legand custom to really show what counties had a lot of spills and what counties didnt.

# %%
#save map
countiesmap.save('County_Data_Map.html')

# %% [markdown]
# #### These maps really help us answer the question, "in what location are most of these spills happening?". We have a broad overview of the spills looking at it by state and we can pinpoint the spills better by looking at which counties they occured in. For me, this brought up the question of are there more spills in each state/county because they have more pipelines/pipline compnaies? SOmething I could do next is find data on the number of piplines within each state/county and get the proportion of pipelines that have a spill in relation to the total number.

# %%
#export data
df.to_csv(r'C:\Users\byl19\Acheivment 6\Acheivment 6\02 Data\Prepared Data\Cleaned-Oil-Data.csv', index = False)
